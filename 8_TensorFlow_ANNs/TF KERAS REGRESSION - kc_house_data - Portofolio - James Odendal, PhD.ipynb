# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('../DATA/kc_house_data.csv')

#https://www.kaggle.com/harlfoxem/housesalesprediction

# %%
#no missing data based on code below
#df.isnull() - this line of code shows visaully in tables where data is mussing
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  21597.000000  21597.000000  21597.000000
# mean   1.509941e+04      1.494096      0.007547      0.234292      3.409825
# ...

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
plt.figure(figsize = (12,8))
sns.distplot(df['price'])

# %%
plt.figure(figsize = (12,8))
sns.countplot(df['bedrooms'])

# %%
#sns.pairplot(df)

# %%
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016772  0.001150   0.005162    -0.012241 -0.131911
# price         -0.016772  1.000000  0.308787   0.525906     0.701917  0.089876
# bedrooms       0.001150  0.308787  1.000000   0.514508     0.578212  0.032471
# bathrooms      0.005162  0.525906  0.514508   1.000000     0.755758  0.088373
# sqft_living   -0.012241  0.701917  0.578212   0.755758     1.000000  0.173453
# sqft_lot      -0.131911  0.089876  0.032471   0.088373     0.173453  1.000000
# floors         0.018608  0.256804  0.177944   0.502582     0.353953 -0.004814
# waterfront    -0.002727  0.266398 -0.006834   0.063744     0.103854  0.021632
# view           0.011536  0.397370  0.080008   0.188386     0.284709  0.074900
# condition     -0.023803  0.036056  0.026496  -0.126479    -0.059445 -0.008830
# grade          0.008188  0.667951  0.356563   0.665838     0.762779  0.114731
# ...

# %%
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
#explore strongly correlated features using scatterplot : Price vs sqft_living


plt.figure(figsize = (12,8)) #Increases the plot size
sns.scatterplot(x = 'price', y = 'sqft_living', data = df)

# %%
#explore strongly correlated features using scatterplot : Price vs bedrooms


plt.figure(figsize = (12,8)) #Increases the plot size
sns.boxplot(x = 'bedrooms', y = 'price', data = df)

# %%
#explore strongly correlated features using scatterplot : Price vs grade


plt.figure(figsize = (12,8)) #Increases the plot size
sns.boxplot(x = 'grade', y = 'price', data = df)

# %%
#explore strongly correlated features using scatterplot : Price vs sqft_above


plt.figure(figsize = (12,8)) #Increases the plot size
sns.scatterplot(x = 'sqft_above', y = 'price', data = df)

# %%
#explore strongly correlated features using scatterplot : Price vs sqft_above


plt.figure(figsize = (12,8)) #Increases the plot size
sns.scatterplot(x = 'price', y = 'sqft_above', data = df)

# %%
plt.figure(figsize = (12,6)) #Increases the plot size
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
plt.figure(figsize = (12,8)) #Increases the plot size
sns.scatterplot(x = 'price', y = 'long', data = df)

# %%
plt.figure(figsize = (12,8)) #Increases the plot size
sns.scatterplot(x = 'price', y = 'lat', data = df)

# %%
plt.figure(figsize = (12,8)) #Increases the plot size
sns.scatterplot(x = 'long', y = 'lat', data = df)

# %%
plt.figure(figsize = (12,8)) #Increases the plot size
sns.scatterplot(x = 'long', y = 'lat', data = df, hue = 'price')

# %%
df.sort_values('price', ascending = False).head(20)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
len(df)
# Out:
# 21597

# %%
len(df)*0.01
# Out:
# 215.97

# %%
non_top_1_perc = df.sort_values('price', ascending = False).iloc[216:]

# %%
non_top_1_perc
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 6329    824059321    6/2/2014  1970000.0         4       3.50         4370
# 12271  1923000260  10/15/2014  1960000.0         5       4.50         6200
# 9166   3124059023   2/13/2015  1960000.0         3       1.75         3330
# 12565  2806300065   4/22/2015  1960000.0         4       4.00         4430
# 1150   4055701200   4/21/2015  1960000.0         4       2.75         3120
# ...           ...         ...        ...       ...        ...          ...
# 2139   1623049041    5/8/2014    82500.0         2       1.00          520
# 8267   3883800011   11/5/2014    82000.0         3       1.00          860
# 16184  3028200080   3/24/2015    81000.0         2       1.00          730
# 465    8658300340   5/23/2014    80000.0         1       0.75          430
# 15279    40000362    5/6/2014    78000.0         2       1.00          780
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
plt.figure(figsize = (12,8)) #Increases the plot size
sns.scatterplot(x = 'long', y = 'lat', data = non_top_1_perc, hue = 'price')

# %%
plt.figure(figsize = (12,8)) #Increases the plot size
#without edgecolor and alpha (0.2)
sns.scatterplot(x = 'long', y = 'lat', data = non_top_1_perc, edgecolor = None, alpha = 0.2, hue = 'price')

# %%
plt.figure(figsize = (12,8)) #Increases the plot size
#new palette
sns.scatterplot(x = 'long', y = 'lat', data = non_top_1_perc, edgecolor = None, palette = 'RdYlGn', alpha = 0.2, hue = 'price')

# %%
sns.boxplot(x = 'waterfront', y = 'price', data = df)

# %%
sns.boxplot(x = 'waterfront', y = 'price', data = non_top_1_perc)

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df = df.drop('id', axis = 1)

# %%
df
# Out:
#              date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      10/13/2014  221900.0         3       1.00         1180      5650
# 1       12/9/2014  538000.0         3       2.25         2570      7242
# 2       2/25/2015  180000.0         2       1.00          770     10000
# 3       12/9/2014  604000.0         4       3.00         1960      5000
# 4       2/18/2015  510000.0         3       2.00         1680      8080
# ...           ...       ...       ...        ...          ...       ...
# 21592   5/21/2014  360000.0         3       2.50         1530      1131
# 21593   2/23/2015  400000.0         4       2.50         2310      5813
# 21594   6/23/2014  402101.0         2       0.75         1020      1350
# 21595   1/16/2015  400000.0         3       2.50         1600      2388
# 21596  10/15/2014  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
df['date']
# Out:
# 0        10/13/2014
# 1         12/9/2014
# 2         2/25/2015
# 3         12/9/2014
# 4         2/18/2015
#             ...
# 21592     5/21/2014
# 21593     2/23/2015
# 21594     6/23/2014
# 21595     1/16/2015
# 21596    10/15/2014
# Name: date, Length: 21597, dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21595   2015-01-16
# 21596   2014-10-15
# Name: date, Length: 21597, dtype: datetime64[ns]

# %%
def year_extraction(date):
    return date.year

# %%
#feature engineering with respect to data

df['year'] = df['date'].apply(lambda date: date.year)
df['month'] = df['date'].apply(lambda date: date.month)
df['day'] = df['date'].apply(lambda date: date.day)

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  yr_built  yr_renovated  zipcode      lat  \
# 0           0     0          3  ...      1955             0    98178  47.5112
# 1           0     0          3  ...      1951          1991    98125  47.7210
# 2           0     0          3  ...      1933             0    98028  47.7379
# 3           0     0          5  ...      1965             0    98136  47.5208
# 4           0     0          3  ...      1987             0    98074  47.6168
#
# ...

# %%
plt.figure(figsize = (12,8)) #Increases the plot size
sns.boxplot(x = 'month', y = 'price', data = df)

# %%
plt.figure(figsize = (12,8)) #Increases the plot size
df.groupby('month').mean()['price'].plot()

# %%
plt.figure(figsize = (12,8)) #Increases the plot size
sns.boxplot(x = 'year', y = 'price', data = df)

# %%
plt.figure(figsize = (12,8)) #Increases the plot size
df.groupby('year').mean()['price'].plot()

# %%
plt.figure(figsize = (12,8)) #Increases the plot size
sns.boxplot(x = 'day', y = 'price', data = df)

# %%
plt.figure(figsize = (12,8)) #Increases the plot size
df.groupby('day').mean()['price'].plot()

# %%
df = df.drop('date', axis = 1)

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'year', 'month', 'day'],
#       dtype='object')

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  ...  yr_built  yr_renovated  zipcode      lat  \
# 0     0          3      7  ...      1955             0    98178  47.5112
# 1     0          3      7  ...      1951          1991    98125  47.7210
# 2     0          3      6  ...      1933             0    98028  47.7379
# 3     0          5      7  ...      1965             0    98136  47.5208
# 4     0          3      8  ...      1987             0    98074  47.6168
#
#       long  sqft_living15  sqft_lot15  year  month  day
# ...

# %%
df['zipcode'].value_counts()
# Out:
# 98103    602
# 98038    589
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    104
# 98010    100
# 98024     80
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %%
df = df.drop('zipcode', axis = 1)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  ...  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7  ...              0      1955             0
# 1     0          3      7  ...            400      1951          1991
# 2     0          3      6  ...              0      1933             0
# 3     0          5      7  ...            910      1965             0
# 4     0          3      8  ...              0      1987             0
#
#        lat     long  sqft_living15  sqft_lot15  year  month  day
# ...

# %%
df['yr_renovated'].value_counts()
# Out:
# 0       20683
# 2014       91
# 2013       37
# 2003       36
# 2000       35
#         ...
# 1934        1
# 1959        1
# 1951        1
# 1948        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df['sqft_basement'].value_counts()
# Out:
# 0       13110
# 600       221
# 700       218
# 500       214
# 800       206
#         ...
# 792         1
# 2590        1
# 935         1
# 2390        1
# 248         1
# Name: sqft_basement, Length: 306, dtype: int64

# %%
X = df.drop('price', axis = 1).values
y = df['price'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
#scaling is done post split


from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

# %%
X_train.shape
# Out:
# (15117, 20)

# %%
model = Sequential()

model.add(Dense(20, activation = 'relu'))
model.add(Dense(20, activation = 'relu'))
model.add(Dense(20, activation = 'relu'))
model.add(Dense(20, activation = 'relu'))

model.add(Dense(1))

model.compile(optimizer = 'adam', loss = 'mse')

# %%
model.fit(x = X_train, y = y_train,
          validation_data = (X_test, y_test), 
         batch_size = 128, epochs = 400)
# Out:
# Epoch 1/400
# 119/119 [==============================] - 0s 2ms/step - loss: 430239580160.0000 - val_loss: 418906734592.0000
# Epoch 2/400
# 119/119 [==============================] - 0s 1ms/step - loss: 428980764672.0000 - val_loss: 414538727424.0000
# Epoch 3/400
# 119/119 [==============================] - 0s 1ms/step - loss: 411609366528.0000 - val_loss: 375016914944.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 1ms/step - loss: 329321119744.0000 - val_loss: 245054472192.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 1ms/step - loss: 177491361792.0000 - val_loss: 113713348608.0000
# Epoch 6/400
# 119/119 [==============================] - 0s 1ms/step - loss: 106060619776.0000 - val_loss: 98069635072.0000
# Epoch 7/400
# 119/119 [==============================] - 0s 1ms/step - loss: 100565811200.0000 - val_loss: 96449290240.0000
# Epoch 8/400
# ...

# %%
model.history.history
# Out:
# {'loss': [430239580160.0,
#   428980764672.0,
#   411609366528.0,
#   329321119744.0,
#   177491361792.0,
#   106060619776.0,
#   100565811200.0,
#   98835939328.0,
#   97111949312.0,
#   95334416384.0,
#   93506633728.0,
#   91619483648.0,
#   89617760256.0,
#   87541956608.0,
#   85383733248.0,
#   83116064768.0,
#   80655400960.0,
#   78284136448.0,
#   75832262656.0,
#   73239085056.0,
#   70620667904.0,
#   67900301312.0,
#   65196769280.0,
#   62599966720.0,
#   60157108224.0,
#   57980977152.0,
#   56105025536.0,
#   54525509632.0,
#   53197742080.0,
#   52128772096.0,
#   51242565632.0,
#   50438053888.0,
#   49748885504.0,
#   49114779648.0,
#   48563494912.0,
#   48008155136.0,
#   47595130880.0,
#   47078473728.0,
#   46665175040.0,
#   46302998528.0,
#   45900980224.0,
#   45508071424.0,
#   45180170240.0,
#   44761407488.0,
#   44370673664.0,
#   43999850496.0,
#   43603435520.0,
#   43254870016.0,
#   42906083328.0,
#   42649526272.0,
#   42265346048.0,
# ...

# %%
pd.DataFrame(model.history.history)
# Out:
#              loss      val_loss
# 0    4.302396e+11  4.189067e+11
# 1    4.289808e+11  4.145387e+11
# 2    4.116094e+11  3.750169e+11
# 3    3.293211e+11  2.450545e+11
# 4    1.774914e+11  1.137133e+11
# ..            ...           ...
# 395  2.930870e+10  2.715647e+10
# 396  2.932619e+10  2.715105e+10
# 397  2.931477e+10  2.732124e+10
# 398  2.930134e+10  2.721951e+10
# 399  2.925758e+10  2.718133e+10
#
# [400 rows x 2 columns]

# %%
losses = pd.DataFrame(model.history.history)

# %%
plt.figure(figsize = (12,8)) #Increases the plot size
losses.plot()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score

# %%
predictions = model.predict(X_test)

# %%
predictions
# Out:
# array([[398770.72],
#        [600012.4 ],
#        [596405.  ],
#        ...,
#        [401136.28],
#        [560074.2 ],
#        [687989.4 ]], dtype=float32)

# %%
mean_squared_error(y_test, predictions)
# Out:
# 27181335231.19628

# %%
np.sqrt(mean_squared_error(y_test, predictions))
# Out:
# 164867.629421898

# %%
mean_absolute_error(y_test, predictions)
# Out:
# 101905.06049141589

# %%
df['price'].describe()
# Out:
# count    2.159700e+04
# mean     5.402966e+05
# std      3.673681e+05
# min      7.800000e+04
# 25%      3.220000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
  5.402966e+05
# Out:
# 540296.6

# %%
explained_variance_score(y_test, predictions)
# Out:
# 0.7954178833621242

# %%
plt.figure(figsize= (12,8))
plt.scatter(y_test, predictions)
plt.plot(y_test, y_test, 'r')

# %%
df
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21592  360000.0         3       2.50         1530      1131     3.0
# 21593  400000.0         4       2.50         2310      5813     2.0
# 21594  402101.0         2       0.75         1020      1350     2.0
# 21595  400000.0         3       2.50         1600      2388     2.0
# 21596  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  ...  sqft_basement  yr_built  \
# 0               0     0          3      7  ...              0      1955
# ...

# %%
df.drop('price', axis = 1).iloc[0]
# Out:
# bedrooms            3.0000
# bathrooms           1.0000
# sqft_living      1180.0000
# sqft_lot         5650.0000
# floors              1.0000
# waterfront          0.0000
# view                0.0000
# condition           3.0000
# grade               7.0000
# sqft_above       1180.0000
# sqft_basement       0.0000
# yr_built         1955.0000
# yr_renovated        0.0000
# lat                47.5112
# long             -122.2570
# sqft_living15    1340.0000
# sqft_lot15       5650.0000
# year             2014.0000
# month              10.0000
# day                13.0000
# Name: 0, dtype: float64

# %%
single_house = df.drop('price', axis = 1).iloc[0]

# %%
single_house.values
# Out:
# array([ 3.00000e+00,  1.00000e+00,  1.18000e+03,  5.65000e+03,
#         1.00000e+00,  0.00000e+00,  0.00000e+00,  3.00000e+00,
#         7.00000e+00,  1.18000e+03,  0.00000e+00,  1.95500e+03,
#         0.00000e+00,  4.75112e+01, -1.22257e+02,  1.34000e+03,
#         5.65000e+03,  2.01400e+03,  1.00000e+01,  1.30000e+01])

# %%
single_house.values.reshape(-1, 20)
# Out:
# array([[ 3.00000e+00,  1.00000e+00,  1.18000e+03,  5.65000e+03,
#          1.00000e+00,  0.00000e+00,  0.00000e+00,  3.00000e+00,
#          7.00000e+00,  1.18000e+03,  0.00000e+00,  1.95500e+03,
#          0.00000e+00,  4.75112e+01, -1.22257e+02,  1.34000e+03,
#          5.65000e+03,  2.01400e+03,  1.00000e+01,  1.30000e+01]])

# %%
scaler.transform(single_house.values.reshape(-1, 20))
# Out:
# array([[0.2       , 0.08      , 0.08376422, 0.00310751, 0.        ,
#         0.        , 0.        , 0.5       , 0.4       , 0.10785619,
#         0.        , 0.47826087, 0.        , 0.57149751, 0.21760797,
#         0.16193426, 0.00582059, 0.        , 0.81818182, 0.4       ]])

# %%
single_house = scaler.transform(single_house.values.reshape(-1, 20))

# %%
model.predict(single_house)
# Out:
# array([[292185.4]], dtype=float32)

# %%
df.head(1)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3        1.0         1180      5650     1.0           0
#
#    view  condition  grade  ...  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7  ...              0      1955             0
#
#        lat     long  sqft_living15  sqft_lot15  year  month  day
# 0  47.5112 -122.257           1340        5650  2014     10   13
#
# [1 rows x 21 columns]
